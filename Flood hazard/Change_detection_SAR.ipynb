# %% [markdown]
# Change detection. In thi part we will do a subration between the image pre and post disaster in order to get only the flood areas

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage import data, filters
from PIL import Image
from skimage.filters import threshold_minimum, threshold_triangle
from skimage import io

# %%
image_water_pre = Image.open("/hkfs/home/haicore/hgf_dlr/hgf_uyx7543/triangle_part_1_2023-06-27_water_pre.png")
image_water_post = Image.open("/hkfs/home/haicore/hgf_dlr/hgf_uyx7543/triangle_part_2_2023-09-07_water_post.png")

# %%
# Convert the image to a NumPy array
image_array_pre = np.array(image_water_pre)
image_array_post = np.array(image_water_post)

# %%
gray1 = np.dot(image_array_pre[..., :3], [0.2989, 0.5870, 0.1140])
gray2 = np.dot(image_array_post[..., :3], [0.2989, 0.5870, 0.1140])

# %%
gray2.shape
# Out:
# (3000, 1000)

# %%
image_array_pre.shape
# Out:
# (3000, 1000, 4)

# %%
CD=gray2 -gray1

# %%
show=False

fig, ax = plt.subplots(figsize=(25,19.95) if not show else (20, 20))
plt.axis('off')
plt.imshow(CD)

# Save the plot without the white border
plt.savefig('p.png', transparent=True, bbox_inches='tight', pad_inches=0)

# %%
image = Image.open("/hkfs/home/haicore/hgf_dlr/hgf_uyx7543/p.png")

# %%
image = np.array(image)

# %%
gray_image = np.dot(image[..., :3], [0.2989, 0.5870, 0.1140])

# %%
# Extract X and Y positions
min=0
X1=[]
Y1=[]
for y in range(gray_image.shape[0]):
    for x in range(gray_image.shape[1]):

        # Check if the pixels are red with lower and upper value 
        if (gray_image[y, x]<75).all():
            
            X1.append(x)
            Y1.append(y)
        else:
            #intensity_values_pixels.append(0)
            X1.append(0)
            Y1.append(0)

# %%
fig, ax = plt.subplots(figsize=(10,40) if not show else (20, 20))
# Plot the blue pixel positions
ax.scatter(X1, Y1, c='blue')
# Rotate the plot counterclockwise by 180 degrees
plt.axis('off')
# Set the background color to transparent
fig.patch.set_alpha(0)
# Invert the x-axis
plt.gca().invert_xaxis()  # Invert the x-axis
# Rotate the image 180 degrees
plt.gca().invert_yaxis()
plt.gca().invert_xaxis()

plt.axis('off')

# Remove the white border
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)

# Save the plot with a transparent background
plt.savefig('CD_part_2.png', transparent=True)

# %%
show=False

fig, ax = plt.subplots(figsize=(60,45) if not show else (40, 40))
# Plot the blue pixel positions
ax.scatter(X1, Y1, c='blue')
# Rotate the plot counterclockwise by 180 degrees
plt.axis('off')
# Set the background color to transparent
#fig.patch.set_alpha(0)
# Invert the x-axis
plt.gca().invert_xaxis()  # Invert the x-axis
# Rotate the image 180 degrees
plt.gca().invert_yaxis()
plt.gca().invert_xaxis()

plt.axis('off')

# Remove the white border
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)

# Save the plot without the white border
#plt.savefig('CD.png', facecolor='#8B4513', bbox_inches='tight', pad_inches=0)
